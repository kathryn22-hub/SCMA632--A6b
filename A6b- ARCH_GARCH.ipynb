# %% [markdown]
# # Imported the data

# %%
import yfinance as yf
# Get the data for tatamotors
ticker = "INFY.NS"  

# Download the data
data = yf.download(ticker, start="2021-04-01", end="2024-03-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
market = data["Adj Close"]
returns = 100 * market.pct_change().dropna() # Volatility

# %%
from arch import arch_model
# Fit an ARCH model
arch_model_fit = arch_model(data['Returns'], vol='ARCH', p=1).fit(disp='off')
print(arch_model_fit.summary())

# Plot the conditional volatility
arch_model_fit.conditional_volatility.plot(title='Conditional Volatility (ARCH)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from arch import arch_model
#       2 # Fit an ARCH model
#       3 arch_model_fit = arch_model(data['Returns'], vol='ARCH', p=1).fit(disp='off')
#
# ModuleNotFoundError: No module named 'arch'

# %%
# Fit a GARCH model
garch_model_fit = arch_model(data['Returns'], vol='Garch', p=1, q=1).fit(disp='off')
print(garch_model_fit.summary())

# Plot the conditional volatility
garch_model_fit.conditional_volatility.plot(title='Conditional Volatility (GARCH)')
plt.show()
# Out:
# C:\Users\Patil\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002322. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                Returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                2056.20
# Distribution:                  Normal   AIC:                          -4104.40
# Method:            Maximum Likelihood   BIC:                          -4085.97
#                                         No. Observations:                  739
# Date:                Wed, Jul 24 2024   Df Residuals:                      738
# Time:                        16:35:57   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         8.8374e-04  6.115e-04      1.445      0.148 [-3.147e-04,2.082e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      9.1208e-05  3.046e-05      2.995  2.748e-03 [3.151e-05,1.509e-04]
# alpha[1]       0.2069      0.116      1.779  7.517e-02  [-2.099e-02,  0.435]
# beta[1]        0.4237      0.177      2.400  1.640e-02   [7.769e-02,  0.770]
# ============================================================================
#
# Covariance estimator: robust

# %%
am = arch_model(returns, vol="Garch", p=1, o=0, q=1, dist="Normal")
res = am.fit(update_freq=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 am = arch_model(returns, vol="Garch", p=1, o=0, q=1, dist="Normal")
#       2 res = am.fit(update_freq=5)
#
# NameError: name 'arch_model' is not defined

# %%
forecasts = res.forecast()

# %%
type(forecasts)
# Out:
# arch.univariate.base.ARCHModelForecast

# %%
data.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-03-21  1564.000000  1576.949951  1543.400024  1554.699951  1545.986816
# 2024-03-22  1521.000000  1528.900024  1498.199951  1508.849976  1500.393799
# 2024-03-26  1492.000000  1507.449951  1487.900024  1492.650024  1484.284668
# 2024-03-27  1496.000000  1499.000000  1481.550049  1483.849976  1475.533936
# 2024-03-28  1487.150024  1511.800049  1487.150024  1498.050049  1489.654419
#
#               Volume   Returns
# Date
# 2024-03-21  11062497 -0.000161
# 2024-03-22  14673890 -0.029935
# 2024-03-26   8351081 -0.010795
# 2024-03-27   6857402 -0.005913
# 2024-03-28  12499530  0.009524

# %%
print(forecasts.mean.iloc[-3:])
print(forecasts.residual_variance.iloc[-3:])
print(forecasts.variance.iloc[-3:])
# Out:
#                  h.1
# Date
# 2024-03-28  0.093024
#                  h.1
# Date
# 2024-03-28  1.979872
#                  h.1
# Date
# 2024-03-28  1.979872

# %%
forecasts = res.forecast(horizon=90)
print(forecasts.residual_variance.iloc[-3:])
# Out:
#                 h.01     h.02      h.03      h.04      h.05      h.06  \
# Date
# 2024-03-28  1.979872  2.15355  2.260601  2.326584  2.367255  2.392323
#
#                 h.07      h.08     h.09      h.10  ...      h.81      h.82  \
# Date                                               ...
# 2024-03-28  2.407775  2.417299  2.42317  2.426788  ...  2.432602  2.432602
#
#                 h.83      h.84      h.85      h.86      h.87      h.88  \
# Date
# 2024-03-28  2.432602  2.432602  2.432602  2.432602  2.432602  2.432602
#
#                 h.89      h.90
# Date
# 2024-03-28  2.432602  2.432602
#
# [1 rows x 90 columns]

# %%
forecasts.residual_variance
# Out:
#                 h.01     h.02      h.03      h.04      h.05      h.06  \
# Date
# 2024-03-28  1.979872  2.15355  2.260601  2.326584  2.367255  2.392323
#
#                 h.07      h.08     h.09      h.10  ...      h.81      h.82  \
# Date                                               ...
# 2024-03-28  2.407775  2.417299  2.42317  2.426788  ...  2.432602  2.432602
#
#                 h.83      h.84      h.85      h.86      h.87      h.88  \
# Date
# 2024-03-28  2.432602  2.432602  2.432602  2.432602  2.432602  2.432602
#
#                 h.89      h.90
# Date
# 2024-03-28  2.432602  2.432602
#
# [1 rows x 90 columns]

# %%
fig = res.plot(annualize="D")
